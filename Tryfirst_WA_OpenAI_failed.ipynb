# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandrocuauhtemoc/OpenSourceLLMs/blob/main/Tryfirst_WA_OpenAI_failed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Selenium
# !pip install selenium

# Install Chrome
# !apt-get update
# !apt install -y chromium-chromedriver

# Link ChromeDriver to the appropriate path
# !ln -s /usr/lib/chromium-browser/chromium-browser /usr/bin/google-chrome
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 41.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.0/476.0 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,160 kB]
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Configure Chrome to run in headless mode
chrome_options = Options()
chrome_options.add_argument('--headless')        # Runs Chrome in headless mode
chrome_options.add_argument('--no-sandbox')      # Bypass OS security model
chrome_options.add_argument('--disable-dev-shm-usage')  # Overcomes limited resource problems

# Define the driver path and initialize the Chrome WebDriver with the options
webdriver_service = Service('/usr/lib/chromium-browser/chromedriver')
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Now we can use this driver to automate Chrome.
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-4-c9279edf8fec> in <cell line: 13>()
#      11 # Define the driver path and initialize the Chrome WebDriver with the options
#      12 webdriver_service = Service('/usr/lib/chromium-browser/chromedriver')
# ---> 13 driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)
#      14
#      15 # Now we can use this driver to automate Chrome.
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import os

# Configure Chrome to run in headless mode
chrome_options = Options()
chrome_options.add_argument('--headless')        # Runs Chrome in headless mode
chrome_options.add_argument('--no-sandbox')      # Bypass OS security model
chrome_options.add_argument('--disable-dev-shm-usage')  # Overcomes limited resource problems

# Define the driver path, trying to find it automatically if the default fails
# Find the chromedriver executable in the usual location for the chromium-chromedriver package
chromedriver_path = '/usr/bin/chromedriver'

# If the chromedriver is not found in the default location, try another possible location.
if not os.path.exists(chromedriver_path):
    chromedriver_path = '/usr/lib/chromium-browser/chromedriver'

webdriver_service = Service(chromedriver_path)  # Use the found or default path

# Initialize the Chrome WebDriver with the options and service
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Now we can use this driver to automate Chrome.
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-0876d3de6535> in <cell line: 23>()
#      21
#      22 # Initialize the Chrome WebDriver with the options and service
# ---> 23 driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)
#      24
#      25 # Now we can use this driver to automate Chrome.
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      53
# ...

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver -y
# !which chromedriver
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Configure Chrome to run in headless mode
chrome_options = Options()
chrome_options.add_argument('--headless')        # Runs Chrome in headless mode
chrome_options.add_argument('--no-sandbox')      # Bypass OS security model
chrome_options.add_argument('--disable-dev-shm-usage')  # Overcomes limited resource problems

# Get the path to the chromedriver executable using 'which' command
chromedriver_path = !which chromedriver
chromedriver_path = chromedriver_path[0]  # Extract the path from the output list

webdriver_service = Service(chromedriver_path)  # Use the dynamically found path

# Initialize the Chrome WebDriver with the options and service
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Now we can use this driver to automate Chrome.
# Out:
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver -y
# !which chromedriver
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Configure Chrome to run in headless mode
chrome_options = Options()
chrome_options.add_argument('--headless=new')  # Runs Chrome in headless mode, try 'new' for newer Chrome versions
chrome_options.add_argument('--no-sandbox')      # Bypass OS security model
chrome_options.add_argument('--disable-dev-shm-usage')  # Overcomes limited resource problems
chrome_options.add_argument('--window-size=1920,1080') # Set window size for headless mode

# Get the path to the chromedriver executable using 'which' command
chromedriver_path = !which chromedriver
chromedriver_path = chromedriver_path[0]  # Extract the path from the output list

webdriver_service = Service(chromedriver_path)  # Use the dynamically found path

# Initialize the Chrome WebDriver with the options and service
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Now we can use this driver to automate Chrome.
# Out:
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Ign:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# Check Chrome version
# !google-chrome --version

# Check ChromeDriver version
# !chromedriver --version
# Out:
# /bin/bash: line 1: google-chrome: command not found
#
# Command '/usr/bin/chromedriver' requires the chromium snap to be installed.
# Please install it with:
#
# snap install chromium

# %%
# Remove any existing chromedriver installations
# !apt-get purge google-chrome-stable
# !apt-get remove chromium-browser
# !apt-get autoremove

# Re-install Chrome and ChromeDriver with compatible versions
# !apt-get update
# !apt install -y chromium-chromedriver
# !ln -s /usr/lib/chromium-browser/chromium-browser /usr/bin/google-chrome

# Confirm versions again
# !google-chrome --version
# !chromedriver --version
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package google-chrome-stable
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   apparmor libfuse3-3 liblzo2-2 snapd squashfs-tools systemd-hwe-hwdb udev
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   chromium-browser chromium-chromedriver
# 0 upgraded, 0 newly installed, 2 to remove and 50 not upgraded.
# After this operation, 243 kB disk space will be freed.
# (Reading database ... 124087 files and directories currently installed.)
# Removing chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Removing chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Reading package lists... Done
# Building dependency tree... Done
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set options for headless mode and disable sandboxing
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Set the correct path to ChromeDriver explicitly
webdriver_service = Service('/usr/lib/chromium-browser/chromedriver')

# Initialize the Chrome WebDriver
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Now the driver is ready for automation
driver.get("https://web.whatsapp.com")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-10-484e07b58317> in <cell line: 15>()
#      13
#      14 # Initialize the Chrome WebDriver
# ---> 15 driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)
#      16
#      17 # Now the driver is ready for automation
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      53
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set options for headless mode and disable sandboxing
chrome_options = Options()
chrome_options.add_argument('--headless=new')  # Use 'new' for headless in newer Chrome versions
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Automatically find the path to ChromeDriver using webdriver-manager (optional but recommended)
# If you're using webdriver-manager, uncomment the lines below:
# !pip install webdriver-manager
# from webdriver_manager.chrome import ChromeDriverManager
# webdriver_service = Service(ChromeDriverManager().install())

# If you're not using webdriver-manager and want to set the path manually:
# First, get the path to ChromeDriver with:
# !which chromedriver
# Then, update the path below if it's different:
webdriver_service = Service('/usr/lib/chromium-browser/chromedriver')

# Initialize the Chrome WebDriver
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Now the driver is ready for automation
driver.get("https://web.whatsapp.com")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-11-ef6bf2d70a8b> in <cell line: 24>()
#      22
#      23 # Initialize the Chrome WebDriver
# ---> 24 driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)
#      25
#      26 # Now the driver is ready for automation
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      53
# ...

# %%
# !google-chrome --version
    # !chromedriver --version
# Out:
#   File "<ipython-input-17-7b7b264c58be>", line 2
#     get_ipython().system('chromedriver --version')
#     ^
# IndentationError: unexpected indent

# %%
# Remove Chrome and ChromeDriver to ensure a clean install
# !apt-get remove -y chromium-browser google-chrome-stable
# !apt-get purge -y chromium-chromedriver
# !apt-get autoremove -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package google-chrome-stable
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   apparmor chromium-browser libfuse3-3 liblzo2-2 snapd squashfs-tools systemd-hwe-hwdb udev
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   chromium-chromedriver*
# 0 upgraded, 0 newly installed, 1 to remove and 50 not upgraded.
# After this operation, 77.8 kB disk space will be freed.
# (Reading database ... 124087 files and directories currently installed.)
# Removing chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages will be REMOVED:
# ...

# %%
# Install Chrome version 91 and the matching ChromeDriver
# !apt-get update
# !apt-get install -y wget
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get -f install -y  # Fix any dependency issues

# Install matching ChromeDriver for Chrome 91
# !wget https://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_linux64.zip
# !unzip chromedriver_linux64.zip
# !chmod +x chromedriver
# !mv chromedriver /usr/local/bin/chromedriver
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set Chrome options for headless mode and disable security restrictions
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Use the newly installed ChromeDriver
webdriver_service = Service('/usr/local/bin/chromedriver')

# Initialize the WebDriver
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Test by opening a webpage
driver.get("https://www.google.com")
print(driver.title)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-16-2969ee835a49> in <cell line: 15>()
#      13
#      14 # Initialize the WebDriver
# ---> 15 driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)
#      16
#      17 # Test by opening a webpage
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      64
#      65         try:
# ...

# %%
# Remove Chrome and ChromeDriver to ensure a clean install
# !apt-get remove -y chromium-browser google-chrome-stable
# !apt-get purge -y chromium-chromedriver
# !apt-get autoremove -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'chromium-browser' is not installed, so not removed
# The following packages were automatically installed and are no longer required:
#   libvulkan1 mesa-vulkan-drivers
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   google-chrome-stable
# 0 upgraded, 0 newly installed, 1 to remove and 50 not upgraded.
# After this operation, 361 MB disk space will be freed.
# (Reading database ... 123942 files and directories currently installed.)
# Removing google-chrome-stable (129.0.6668.100-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'chromium-chromedriver' is not installed, so not removed
# The following packages were automatically installed and are no longer required:
#   libvulkan1 mesa-vulkan-drivers
# ...

# %%
# Install Chrome version 91 and the matching ChromeDriver
# !apt-get update
# !apt-get install -y wget
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get -f install -y  # Fix any dependency issues

# Install matching ChromeDriver for Chrome 91
# !wget https://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_linux64.zip
# !unzip chromedriver_linux64.zip
# !chmod +x chromedriver
# !mv chromedriver /usr/local/bin/chromedriver
# Out:
# Get:1 https://dl.google.com/linux/chrome/deb stable InRelease [1,825 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Get:5 https://dl.google.com/linux/chrome/deb stable/main amd64 Packages [1,090 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 2,915 B in 1s (2,034 B/s)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set Chrome options for headless mode and disable security restrictions
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Use the newly installed ChromeDriver
webdriver_service = Service('/usr/local/bin/chromedriver')

# Initialize the WebDriver
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Test by opening a webpage
driver.get("https://www.google.com")
print(driver.title)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-20-2969ee835a49> in <cell line: 15>()
#      13
#      14 # Initialize the WebDriver
# ---> 15 driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)
#      16
#      17 # Test by opening a webpage
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      64
#      65         try:
# ...

# %%
# Install Chrome version 91 and the matching ChromeDriver
# !apt-get update
# !apt-get install -y wget
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get -f install -y  # Fix any dependency issues

# Install matching ChromeDriver for Chrome 91
# !wget https://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_linux64.zip
# !unzip chromedriver_linux64.zip
# !chmod +x chromedriver
# !mv chromedriver /usr/local/bin/chromedriver

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set Chrome options for headless mode, disable security restrictions, and specify binary location
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
# Specify the path to the Chrome binary for version 91
chrome_
# Out:
# Hit:1 https://dl.google.com/linux/chrome/deb stable InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Fetched 257 kB in 2s (132 kB/s)
# Reading package lists... Done
# ...

# %%
# Install Chrome version 91 and the matching ChromeDriver
# !apt-get update
# !apt-get install -y wget
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get -f install -y  # Fix any dependency issues

# Install matching ChromeDriver for Chrome 91
# !wget https://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_linux64.zip
# !unzip chromedriver_linux64.zip
# !chmod +x chromedriver
# !mv chromedriver /usr/local/bin/chromedriver

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set Chrome options for headless mode, disable security restrictions, and specify binary location
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
# Specify the path to the Chrome binary for version 91
chrome_options.binary_location = '/usr/bin/google-chrome-stable' # Update if your Chrome 91 binary is located elsewhere

# Use the newly installed ChromeDriver
webdriver_service = Service('/usr/local/bin/chromedriver')

# Initialize the WebDriver
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Test by opening a webpage
driver.get("https://www.google.com")
print(driver.title)
# Out:
# Hit:1 https://dl.google.com/linux/chrome/deb stable InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Ign:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# Install Chrome version 91 and the matching ChromeDriver
# !apt-get update
# !apt-get install -y wget
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get -f install -y  # Fix any dependency issues

# Install matching ChromeDriver for Chrome 91
# !wget https://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_linux64.zip
# !unzip chromedriver_linux64.zip
# !chmod +x chromedriver
# !mv chromedriver /usr/local/bin/chromedriver

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set Chrome options for headless mode, disable security restrictions, and specify binary location
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
# Specify the path to the Chrome binary for version 91
# This path might be different if you are using a non-standard installation
# Use !which google-chrome to find the location if necessary
chrome_options.binary_location = '/usr/bin/google-chrome'

# Use the newly installed ChromeDriver
webdriver_service = Service('/usr/local/bin/chromedriver')

# Initialize the WebDriver
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Test by opening a webpage
driver.get("https://www.google.com")
print(driver.title)
# Out:
# Hit:1 https://dl.google.com/linux/chrome/deb stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !chmod +x /usr/local/bin/chromedriver

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set Chrome options for headless mode and disable security restrictions
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Use the newly installed ChromeDriver
webdriver_service = Service('/usr/local/bin/chromedriver')

# Initialize the WebDriver
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Test by opening a webpage
driver.get("https://www.google.com")
print(driver.title)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-26-2969ee835a49> in <cell line: 15>()
#      13
#      14 # Initialize the WebDriver
# ---> 15 driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)
#      16
#      17 # Test by opening a webpage
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      64
#      65         try:
# ...
